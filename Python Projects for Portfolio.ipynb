# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
URL = 'https://www.amazon.in/NIKE-Revolution-Mens-Running-Shoes/dp/B0D7MPGBQ9/ref=sr_1_2?crid=3PCVFBUC7H89P&dib=eyJ2IjoiMSJ9.QGFNu6kjJTpNBRAYIzPxKzumgra9wo_y9OR3-VuGYNSE6MyGC-N2YSLj6QCSeWzA5wb2REEVfR-fk6EyRA4VqEQ0QOWN5_pUV8dOPPR1cLXtdT1UKS_NPWYz3wXpK76FnaadAnrwZ4qwlH6Y-9cuatd-eOhUksy-masCAVHYXMlADiE2jcBoxIomTG1J5OQL-wtZ4wee8x5u4gYr7buZSwW8jEwKttBGXc5sszAqanqu1Hz7ddHBzGKtsq8DzG81LJJxW-7RRbFTL2sY2mOQwakxFnNRF7sdtGlhGmeRA-argzcJJHBoivdvx-_Xb2Qn_x5LMLwGSUvqQSavfUmqtjnzwdr1X0LySygJ4GHfP3oJJN7cRMJfIJm9ks1cyx3dG0t6fukG1OQ9WLl8wFKpYhJy46Ldoqg8tV4HpgSTXbqcbhYhFMMcVzd8dvVKuqzX.lPgYkmKTkFAdzcsCz9Q18xAe8_7MSp5U2qR6AqNw9Ds&dib_tag=se&keywords=nike+shoes+for+man&nsdOptOutParam=true&qid=1737535545&sprefix=Nike%2Caps%2C326&sr=8-2'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

#title = soup2.find(id='productTitle').get_text()
title='Nike Running Shoes'

#price = soup2.find(id='a-price-whole').get_text()
price='3500'


print(title)
print(price)

# %%
import datetime

today = datetime.date.today()

print(today)

# %%
# Create CSV and write headers and data into the file

import csv 

header = ['Title', 'Price', 'Date']
data = [title, price, today]


with open('AmazonWebScraperDataset.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Admin\Desktop\ADNANpython\AmazonWebScraperDataset.csv')

print(df)

# %%
with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    URL = 'https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")

    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    title = 'Nike Running Shoes'

    price = '3400'


    import datetime

    today = datetime.date.today()
    
    import csv 

    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)
        
    if price == 3400:
        send_mail()

# %%
while(True):
    check_price()
    time.sleep(60)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Admin\Desktop\ADNANpython\AmazonWebScraperDataset.csv')

print(df)

# %%
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('adnanbestguy@gmail.com','9361206168')
    
    subject = "The Shoe you want is below 3500! Now is your chance to buy!"
    body = "Adnan, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data+analyst+tshirt&qid=1626655184&sr=8-3"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'adnanbestguy@gmail.com',
        msg
     
    )

# %% [markdown]
# ### Automating Crypto Website using  crypto API

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'10',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '9d22a627-0dd9-4fe9-892e-0fb58ef89db3',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2025-01-23T08:47:09.009Z', 'error_code': 0, 'error_message': None, 'elapsed': 13, 'credit_count': 1, 'notice': None, 'total_count': 10712}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11870, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'p
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
df=pd.json_normalize(data['data'])
df
# Out:
#      id         name symbol      slug  num_market_pairs  \
# 0     1      Bitcoin    BTC   bitcoin             11870
# 1  1027     Ethereum    ETH  ethereum              9847
# 2    52          XRP    XRP       xrp              1513
# 3   825  Tether USDt   USDT    tether            114296
# 4  5426       Solana    SOL    solana               832
# 5  1839          BNB    BNB       bnb              2339
# 6    74     Dogecoin   DOGE  dogecoin              1154
# 7  3408         USDC   USDC  usd-coin             25078
# 8  2010      Cardano    ADA   cardano              1451
# 9  1958         TRON    TRX      tron              1109
#
#                  date_added  \
# 0  2010-07-13T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2013-08-04T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
# 5  2017-07-25T00:00:00.000Z
# 6  2013-12-15T00:00:00.000Z
# 7  2018-10-08T00:00:00.000Z
# 8  2017-10-01T00:00:00.000Z
# 9  2017-09-13T00:00:00.000Z
#
# ...

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df['Time_Stamp']=pd.datetime.now()
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17180\546421455.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   df['Time_Stamp']=pd.datetime.now()
#      id         name symbol      slug  num_market_pairs  \
# 0     1      Bitcoin    BTC   bitcoin             11870
# 1  1027     Ethereum    ETH  ethereum              9847
# 2    52          XRP    XRP       xrp              1513
# 3   825  Tether USDt   USDT    tether            114296
# 4  5426       Solana    SOL    solana               832
# 5  1839          BNB    BNB       bnb              2339
# 6    74     Dogecoin   DOGE  dogecoin              1154
# 7  3408         USDC   USDC  usd-coin             25078
# 8  2010      Cardano    ADA   cardano              1451
# 9  1958         TRON    TRX      tron              1109
#
#                  date_added  \
# 0  2010-07-13T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# ...

# %%
def api_runner():
    global df
    from requests import Request, Session
    from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
    import json

    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'10',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '9d22a627-0dd9-4fe9-892e-0fb58ef89db3',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    df=pd.json_normalize(data['data'])
    df['Time_Stamp']=pd.datetime.now()
    df=df.append(df)
    
    if not os.path.isfile(r"C:\Users\Admin\Documents\Pandas\API Pull\API.csv"):
        df.to_csv(r"C:\Users\Admin\Documents\Pandas\API Pull\API.csv",header='column_names')
    else:
        df.to_csv(r"C:\Users\Admin\Documents\Pandas\API Pull\API.csv",mode='a',header=False)

# %%
import os
from time import time
from time import sleep
import datetime

for i in range(333):
    api_runner()
    print("API runner completed")
    sleep(60)
exit()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17180\122827636.py:29: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   df['Time_Stamp']=pd.datetime.now()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17180\122827636.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df)
# API runner completed
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17180\122827636.py:29: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   df['Time_Stamp']=pd.datetime.now()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17180\122827636.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df)
# API runner completed
# ...

# %%
import pandas as pd
df2=pd.read_csv(r"C:\Users\Admin\Documents\Pandas\API Pull\API.csv")
df2
# Out:
#     Unnamed: 0    id         name symbol      slug  num_market_pairs  \
# 0            0     1      Bitcoin    BTC   bitcoin             11870
# 1            1  1027     Ethereum    ETH  ethereum              9847
# 2            2    52          XRP    XRP       xrp              1513
# 3            3   825  Tether USDt   USDT    tether            114296
# 4            4  5426       Solana    SOL    solana               832
# 5            5  1839          BNB    BNB       bnb              2339
# 6            6    74     Dogecoin   DOGE  dogecoin              1154
# 7            7  3408         USDC   USDC  usd-coin             25078
# 8            8  2010      Cardano    ADA   cardano              1451
# 9            9  1958         TRON    TRX      tron              1109
# 10           0     1      Bitcoin    BTC   bitcoin             11870
# 11           1  1027     Ethereum    ETH  ethereum              9847
# 12           2    52          XRP    XRP       xrp              1513
# ...

# %%
pd.set_option('display.float_format',lambda x:'%.5f' %x)
df
# Out:
#      id         name symbol      slug  num_market_pairs  \
# 0     1      Bitcoin    BTC   bitcoin             11870
# 1  1027     Ethereum    ETH  ethereum              9847
# 2    52          XRP    XRP       xrp              1513
# 3   825  Tether USDt   USDT    tether            114296
# 4  5426       Solana    SOL    solana               832
# 5  1839          BNB    BNB       bnb              2339
# 6    74     Dogecoin   DOGE  dogecoin              1154
# 7  3408         USDC   USDC  usd-coin             25078
# 8  2010      Cardano    ADA   cardano              1451
# 9  1958         TRON    TRX      tron              1109
# 0     1      Bitcoin    BTC   bitcoin             11870
# 1  1027     Ethereum    ETH  ethereum              9847
# 2    52          XRP    XRP       xrp              1513
# 3   825  Tether USDt   USDT    tether            114296
# 4  5426       Solana    SOL    solana               832
# 5  1839          BNB    BNB       bnb              2339
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'symbol', 'slug', 'num_market_pairs', 'date_added',
#        'tags', 'max_supply', 'circulating_supply', 'total_supply',
#        'infinite_supply', 'platform', 'cmc_rank',
#        'self_reported_circulating_supply', 'self_reported_market_cap',
#        'tvl_ratio', 'last_updated', 'quote.USD.price', 'quote.USD.volume_24h',
#        'quote.USD.volume_change_24h', 'quote.USD.percent_change_1h',
#        'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d',
#        'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d',
#        'quote.USD.percent_change_90d', 'quote.USD.market_cap',
#        'quote.USD.market_cap_dominance', 'quote.USD.fully_diluted_market_cap',
#        'quote.USD.tvl', 'quote.USD.last_updated', 'platform.id',
#        'platform.name', 'platform.symbol', 'platform.slug',
#        'platform.token_address', 'Time_Stamp'],
#       dtype='object')

# %%
df3=df.groupby('name',sort=False)[['quote.USD.percent_change_1h',
       'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d',
       'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d',
       'quote.USD.percent_change_90d']].mean()

df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -0.37245                      -2.87419
# Ethereum                        -0.50236                      -2.50771
# XRP                             -0.64264                      -1.61954
# Tether USDt                      0.01888                      -0.02627
# Solana                          -0.96577                      -3.32762
# BNB                              0.00965                      -1.44263
# Dogecoin                        -0.76959                      -3.33072
# USDC                             0.01176                       0.00970
# Cardano                         -0.30493                      -2.15186
# TRON                             0.07025                      -0.65691
#
#              quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                          3.45787                       8.50657
# ...

# %%
df4=df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     -0.37245
#              quote.USD.percent_change_24h    -2.87419
#              quote.USD.percent_change_7d      3.45787
#              quote.USD.percent_change_30d     8.50657
#              quote.USD.percent_change_60d     4.13604
#              quote.USD.percent_change_90d    51.09788
# Ethereum     quote.USD.percent_change_1h     -0.50236
#              quote.USD.percent_change_24h    -2.50771
#              quote.USD.percent_change_7d     -3.06325
#              quote.USD.percent_change_30d    -5.42882
#              quote.USD.percent_change_60d    -5.61315
#              quote.USD.percent_change_90d    27.86659
# XRP          quote.USD.percent_change_1h     -0.64264
#              quote.USD.percent_change_24h    -1.61954
#              quote.USD.percent_change_7d      1.29879
#              quote.USD.percent_change_30d    38.47737
#              quote.USD.percent_change_60d   115.10770
# ...

# %%
df5=df4.to_frame(name="values")
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h   -0.37245
#             quote.USD.percent_change_24h  -2.87419
#             quote.USD.percent_change_7d    3.45787
#             quote.USD.percent_change_30d   8.50657
#             quote.USD.percent_change_60d   4.13604
#             quote.USD.percent_change_90d  51.09788
# Ethereum    quote.USD.percent_change_1h   -0.50236
#             quote.USD.percent_change_24h  -2.50771
#             quote.USD.percent_change_7d   -3.06325
#             quote.USD.percent_change_30d  -5.42882
#             quote.USD.percent_change_60d  -5.61315
#             quote.USD.percent_change_90d  27.86659
# XRP         quote.USD.percent_change_1h   -0.64264
#             quote.USD.percent_change_24h  -1.61954
#             quote.USD.percent_change_7d    1.29879
#             quote.USD.percent_change_30d  38.47737
#             quote.USD.percent_change_60d 115.10770
# ...

# %%
df5.count()
# Out:
# values    60
# dtype: int64

# %%
index=pd.Index(range(60))
df6=df5.reset_index()
df6
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.37245
# 1       Bitcoin  quote.USD.percent_change_24h  -2.87419
# 2       Bitcoin   quote.USD.percent_change_7d   3.45787
# 3       Bitcoin  quote.USD.percent_change_30d   8.50657
# 4       Bitcoin  quote.USD.percent_change_60d   4.13604
# 5       Bitcoin  quote.USD.percent_change_90d  51.09788
# 6      Ethereum   quote.USD.percent_change_1h  -0.50236
# 7      Ethereum  quote.USD.percent_change_24h  -2.50771
# 8      Ethereum   quote.USD.percent_change_7d  -3.06325
# 9      Ethereum  quote.USD.percent_change_30d  -5.42882
# 10     Ethereum  quote.USD.percent_change_60d  -5.61315
# 11     Ethereum  quote.USD.percent_change_90d  27.86659
# 12          XRP   quote.USD.percent_change_1h  -0.64264
# 13          XRP  quote.USD.percent_change_24h  -1.61954
# 14          XRP   quote.USD.percent_change_7d   1.29879
# 15          XRP  quote.USD.percent_change_30d  38.47737
# ...

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.37245
# 1       Bitcoin  quote.USD.percent_change_24h  -2.87419
# 2       Bitcoin   quote.USD.percent_change_7d   3.45787
# 3       Bitcoin  quote.USD.percent_change_30d   8.50657
# 4       Bitcoin  quote.USD.percent_change_60d   4.13604
# 5       Bitcoin  quote.USD.percent_change_90d  51.09788
# 6      Ethereum   quote.USD.percent_change_1h  -0.50236
# 7      Ethereum  quote.USD.percent_change_24h  -2.50771
# 8      Ethereum   quote.USD.percent_change_7d  -3.06325
# 9      Ethereum  quote.USD.percent_change_30d  -5.42882
# 10     Ethereum  quote.USD.percent_change_60d  -5.61315
# 11     Ethereum  quote.USD.percent_change_90d  27.86659
# 12          XRP   quote.USD.percent_change_1h  -0.64264
# 13          XRP  quote.USD.percent_change_24h  -1.61954
# 14          XRP   quote.USD.percent_change_7d   1.29879
# 15          XRP  quote.USD.percent_change_30d  38.47737
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h  -0.37245
# 1       Bitcoin            24h  -2.87419
# 2       Bitcoin             7d   3.45787
# 3       Bitcoin            30d   8.50657
# 4       Bitcoin            60d   4.13604
# 5       Bitcoin            90d  51.09788
# 6      Ethereum             1h  -0.50236
# 7      Ethereum            24h  -2.50771
# 8      Ethereum             7d  -3.06325
# 9      Ethereum            30d  -5.42882
# 10     Ethereum            60d  -5.61315
# 11     Ethereum            90d  27.86659
# 12          XRP             1h  -0.64264
# 13          XRP            24h  -1.61954
# 14          XRP             7d   1.29879
# 15          XRP            30d  38.47737
# 16          XRP            60d 115.10770
# 17          XRP            90d 493.57359
# 18  Tether USDt             1h   0.01888
# 19  Tether USDt            24h  -0.02627
# 20  Tether USDt             7d  -0.01736
# 21  Tether USDt            30d   0.08871
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.catplot(x='percent_change',y='values',hue='name',data=df7,kind='point')

# %%
df8=df2[['name','quote.USD.price','Time_Stamp']]
df8=df8.query("name=='Bitcoin'")
df8
# Out:
#        name  quote.USD.price                  Time_Stamp
# 0   Bitcoin     102395.45962  2025-01-23 14:18:21.840530
# 10  Bitcoin     102395.45962  2025-01-23 14:18:21.840530
# 20  Bitcoin     102423.21606  2025-01-23 14:19:22.570234
# 30  Bitcoin     102423.21606  2025-01-23 14:19:22.570234
# 40  Bitcoin     102186.43025  2025-01-23 14:20:22.990891
# 50  Bitcoin     102186.43025  2025-01-23 14:20:22.990891

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='Time_Stamp', y='quote.USD.price', data = df8)
# Out:
# <Axes: xlabel='Time_Stamp', ylabel='quote.USD.price'>
